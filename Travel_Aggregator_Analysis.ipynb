# %%
import pandas as pd

# %% [markdown]
# # 1. Importing the Data

# %%
Bookings_df = pd.read_csv(r"C:\Users\dell\Desktop\edureka_project\edureka_Project_portfolio\Bookings.csv")
Bookings_df
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
Sessions_df = pd.read_csv(r"C:\Users\dell\Desktop\edureka_project\edureka_Project_portfolio\Sessions.csv")
Sessions_df
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 0         2020-01-21T21:10:12Z          NaN
# 1         2020-01-21T21:10:12Z          NaN
# 2         2020-01-21T21:10:12Z          NaN
# 3         2020-01-21T21:10:12Z          NaN
# 4         2020-01-21T21:10:12Z          NaN
# ...

# %% [markdown]
# # 2. Below were the steps taken in Cleaning the Data

# %% [markdown]
# _**Step 1: Checking for Duplicates**_

# %%
Bookings_df = Bookings_df.drop_duplicates()
Bookings_df
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
Sessions_df = Sessions_df.drop_duplicates()
Sessions_df
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 0         2020-01-21T21:10:12Z          NaN
# 1         2020-01-21T21:10:12Z          NaN
# 2         2020-01-21T21:10:12Z          NaN
# 3         2020-01-21T21:10:12Z          NaN
# 4         2020-01-21T21:10:12Z          NaN
# ...

# %% [markdown]
# _**Step 2: Removing Empty cells and dealing with missing values**_

# %%
#Filling empty Values or missing values with empty cells
Sessions_df = Sessions_df.fillna('')
Sessions_df
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 0         2020-01-21T21:10:12Z
# 1         2020-01-21T21:10:12Z
# 2         2020-01-21T21:10:12Z
# 3         2020-01-21T21:10:12Z
# 4         2020-01-21T21:10:12Z
# ...                        ...          ...
# ...

# %% [markdown]
# **Step 3: Dropping rows with missing values**

# %%
#droping  a rows with missing values
for x in Sessions_df.index:
    if Sessions_df.loc[x, "booking_id"] == "":
        Sessions_df.drop(x,inplace=True)
Sessions_df
# Out:
#        session_id    search_id               search_time  \
# 5     session_322   search_506  2020-01-21T21:10:58.482Z
# 6     session_283   search_880  2020-01-21T05:33:48.061Z
# 7     session_194   search_312  2019-09-05T09:04:40.423Z
# 9      session_52  search_1110  2020-01-20T17:03:52.145Z
# 13    session_229   search_695  2019-09-07T22:29:05.439Z
# ...           ...          ...                       ...
# 1479  session_230   search_728      2020-09-24T06:51:44Z
# 1480  session_190   search_215  2020-03-19T01:25:22.092Z
# 1485  session_250   search_579  2020-03-19T09:09:38.901Z
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 5         2020-01-21T21:10:12Z   booking_54
# 6     2020-01-21T05:33:33.559Z  booking_106
# 7         2019-09-05T09:04:32Z    booking_1
# 9     2020-01-20T16:53:47.477Z  booking_282
# 13        2019-09-07T22:00:05Z  booking_240
# ...

# %%
Bookings_df
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %% [markdown]
# #### Reseting Session_df Serial number

# %%
Sessions_df = Sessions_df.reset_index(drop=True)
Sessions_df
# Out:
#       session_id    search_id               search_time  \
# 0    session_322   search_506  2020-01-21T21:10:58.482Z
# 1    session_283   search_880  2020-01-21T05:33:48.061Z
# 2    session_194   search_312  2019-09-05T09:04:40.423Z
# 3     session_52  search_1110  2020-01-20T17:03:52.145Z
# 4    session_229   search_695  2019-09-07T22:29:05.439Z
# ..           ...          ...                       ...
# 334  session_230   search_728      2020-09-24T06:51:44Z
# 335  session_190   search_215  2020-03-19T01:25:22.092Z
# 336  session_250   search_579  2020-03-19T09:09:38.901Z
# 337  session_150   search_156  2018-12-18T22:59:43.764Z
# 338  session_120  search_1180      2021-12-23T17:34:52Z
#
#         session_starting_time   booking_id
# 0        2020-01-21T21:10:12Z   booking_54
# 1    2020-01-21T05:33:33.559Z  booking_106
# 2        2019-09-05T09:04:32Z    booking_1
# 3    2020-01-20T16:53:47.477Z  booking_282
# 4        2019-09-07T22:00:05Z  booking_240
# ...

# %% [markdown]
# _**Step 4: Changing the date:time column of booking_time to a string**_

# %%
Bookings_df["booking_time"].apply(lambda x: str(x))
Bookings_df
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
Sessions_df["search_time"].apply(lambda x: str(x))
Sessions_df["session_starting_time"].apply(lambda x: str(x))
Sessions_df
# Out:
#       session_id    search_id               search_time  \
# 0    session_322   search_506  2020-01-21T21:10:58.482Z
# 1    session_283   search_880  2020-01-21T05:33:48.061Z
# 2    session_194   search_312  2019-09-05T09:04:40.423Z
# 3     session_52  search_1110  2020-01-20T17:03:52.145Z
# 4    session_229   search_695  2019-09-07T22:29:05.439Z
# ..           ...          ...                       ...
# 334  session_230   search_728      2020-09-24T06:51:44Z
# 335  session_190   search_215  2020-03-19T01:25:22.092Z
# 336  session_250   search_579  2020-03-19T09:09:38.901Z
# 337  session_150   search_156  2018-12-18T22:59:43.764Z
# 338  session_120  search_1180      2021-12-23T17:34:52Z
#
#         session_starting_time   booking_id
# 0        2020-01-21T21:10:12Z   booking_54
# 1    2020-01-21T05:33:33.559Z  booking_106
# 2        2019-09-05T09:04:32Z    booking_1
# 3    2020-01-20T16:53:47.477Z  booking_282
# 4        2019-09-07T22:00:05Z  booking_240
# ...

# %%
Bookings_df.dtypes
# Out:
# customer_id           object
# booking_id            object
# from_city             object
# from_country          object
# to_city               object
# to_country            object
# booking_time          object
# device_type_used      object
# INR_Amount           float64
# service_name          object
# no_of_passengers       int64
# days_to_departure      int64
# distance_km          float64
# dtype: object

# %%
Sessions_df.dtypes
# Out:
# session_id               object
# search_id                object
# search_time              object
# session_starting_time    object
# booking_id               object
# dtype: object

# %% [markdown]
# _**Step 5: Changing the date:time string to a datatime object**_

# %%
Bookings_df['booking_time'] = pd.to_datetime(Bookings_df['booking_time'])
Bookings_df
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
# Convert the 'search_time' column to datetime, coercing errors to NaT, this is because the colomuns have inconsistentent values
Sessions_df['search_time'] = pd.to_datetime(Sessions_df['search_time'], errors='coerce')
Sessions_df
# Out:
#       session_id    search_id                      search_time  \
# 0    session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1    session_283   search_880 2020-01-21 05:33:48.061000+00:00
# 2    session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 3     session_52  search_1110 2020-01-20 17:03:52.145000+00:00
# 4    session_229   search_695 2019-09-07 22:29:05.439000+00:00
# ..           ...          ...                              ...
# 334  session_230   search_728                              NaT
# 335  session_190   search_215 2020-03-19 01:25:22.092000+00:00
# 336  session_250   search_579 2020-03-19 09:09:38.901000+00:00
# 337  session_150   search_156 2018-12-18 22:59:43.764000+00:00
# 338  session_120  search_1180                              NaT
#
#         session_starting_time   booking_id
# 0        2020-01-21T21:10:12Z   booking_54
# 1    2020-01-21T05:33:33.559Z  booking_106
# 2        2019-09-05T09:04:32Z    booking_1
# ...

# %%
# Convert the 'search_time' column to datetime, coercing errors to NaT
Sessions_df['session_starting_time'] = pd.to_datetime(Sessions_df['session_starting_time'], errors='coerce')
Sessions_df
# Out:
#       session_id    search_id                      search_time  \
# 0    session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1    session_283   search_880 2020-01-21 05:33:48.061000+00:00
# 2    session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 3     session_52  search_1110 2020-01-20 17:03:52.145000+00:00
# 4    session_229   search_695 2019-09-07 22:29:05.439000+00:00
# ..           ...          ...                              ...
# 334  session_230   search_728                              NaT
# 335  session_190   search_215 2020-03-19 01:25:22.092000+00:00
# 336  session_250   search_579 2020-03-19 09:09:38.901000+00:00
# 337  session_150   search_156 2018-12-18 22:59:43.764000+00:00
# 338  session_120  search_1180                              NaT
#
#         session_starting_time   booking_id
# 0   2020-01-21 21:10:12+00:00   booking_54
# 1                         NaT  booking_106
# 2   2019-09-05 09:04:32+00:00    booking_1
# ...

# %%
Bookings_df.dtypes
# Out:
# customer_id                       object
# booking_id                        object
# from_city                         object
# from_country                      object
# to_city                           object
# to_country                        object
# booking_time         datetime64[ns, UTC]
# device_type_used                  object
# INR_Amount                       float64
# service_name                      object
# no_of_passengers                   int64
# days_to_departure                  int64
# distance_km                      float64
# dtype: object

# %%
Sessions_df.dtypes
# Out:
# session_id                            object
# search_id                             object
# search_time              datetime64[ns, UTC]
# session_starting_time    datetime64[ns, UTC]
# booking_id                            object
# dtype: object

# %%
Sessions_df.head(10)
# Out:
#     session_id    search_id                      search_time  \
# 0  session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1  session_283   search_880 2020-01-21 05:33:48.061000+00:00
# 2  session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 3   session_52  search_1110 2020-01-20 17:03:52.145000+00:00
# 4  session_229   search_695 2019-09-07 22:29:05.439000+00:00
# 5  session_126  search_1140                              NaT
# 6  session_308     search_4 2018-11-09 12:02:36.301000+00:00
# 7  session_309  search_1155                              NaT
# 8  session_107   search_913                              NaT
# 9  session_116   search_384                              NaT
#
#       session_starting_time   booking_id
# 0 2020-01-21 21:10:12+00:00   booking_54
# 1                       NaT  booking_106
# 2 2019-09-05 09:04:32+00:00    booking_1
# 3                       NaT  booking_282
# 4 2019-09-07 22:00:05+00:00  booking_240
# 5 2022-05-12 13:01:12+00:00   booking_67
# ...

# %%
Bookings_df.head(10)
# Out:
#     customer_id   booking_id    from_city from_country            to_city  \
# 0  customer_259   booking_82      Gurgaon        India          Ahmedabad
# 1  customer_303  booking_156        Delhi        India           Brussels
# 2  customer_203   booking_99   Devanhalli        India  Frankfurt am Main
# 3  customer_211  booking_319      Gurgaon        India  Frankfurt am Main
# 4  customer_287  booking_222      Gurgaon        India   Roissy-en-France
# 5   customer_99  booking_241      Gurgaon        India   Roissy-en-France
# 6   customer_28  booking_129      Kolkata        India            Gurgaon
# 7  customer_217   booking_18  Bhubaneswar        India            Durlaga
# 8  customer_161  booking_136      Gurgaon        India          Amsterdam
# 9  customer_150  booking_289        Delhi        India            Hamburg
#
#     to_country              booking_time device_type_used  INR_Amount  \
# 0        India 2020-02-05 16:12:08+00:00          Desktop     2565.28
# ...

# %% [markdown]
# _**Step 6: Remove Rows with NaT, to help the data more cleaner**_

# %%
# Removing rows with NaT in the 'serach_time' column using the dropna funtion
Sessions_df_cleaned = Sessions_df.dropna(subset=['search_time'])

# %%
# Display the cleaned DataFrame
print("\nCleaned DataFrame (NaT values removed):")
# Out:
# Cleaned DataFrame (NaT values removed):

# %%
# Display the cleaned DataFrame
Sessions_df_cleaned
# Out:
#       session_id    search_id                      search_time  \
# 0    session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1    session_283   search_880 2020-01-21 05:33:48.061000+00:00
# 2    session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 3     session_52  search_1110 2020-01-20 17:03:52.145000+00:00
# 4    session_229   search_695 2019-09-07 22:29:05.439000+00:00
# ..           ...          ...                              ...
# 332  session_249  search_1079 2019-07-25 09:53:40.341000+00:00
# 333   session_75   search_203 2019-07-25 19:39:40.210000+00:00
# 335  session_190   search_215 2020-03-19 01:25:22.092000+00:00
# 336  session_250   search_579 2020-03-19 09:09:38.901000+00:00
# 337  session_150   search_156 2018-12-18 22:59:43.764000+00:00
#
#         session_starting_time   booking_id
# 0   2020-01-21 21:10:12+00:00   booking_54
# 1                         NaT  booking_106
# 2   2019-09-05 09:04:32+00:00    booking_1
# ...

# %%
# Removing rows with NaT in the 'session_starting_time' column
Sessions_df_cleaned2 = Sessions_df_cleaned.dropna(subset=['session_starting_time'])

# %%
# Display the cleaned DataFrame
print("\nCleaned DataFrame (NaT values removed):")
# Out:
# Cleaned DataFrame (NaT values removed):

# %%
# Display the cleaned DataFrame
Sessions_df_cleaned2
# Out:
#       session_id    search_id                      search_time  \
# 0    session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 2    session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 4    session_229   search_695 2019-09-07 22:29:05.439000+00:00
# 10   session_285   search_216 2019-09-03 17:29:53.394000+00:00
# 14   session_160   search_451 2020-01-26 13:35:35.117000+00:00
# ..           ...          ...                              ...
# 310  session_161  search_1147 2020-02-04 18:37:12.045000+00:00
# 312  session_135  search_1197 2020-03-18 16:57:45.171000+00:00
# 322   session_56   search_555 2020-03-16 23:44:39.576000+00:00
# 332  session_249  search_1079 2019-07-25 09:53:40.341000+00:00
# 337  session_150   search_156 2018-12-18 22:59:43.764000+00:00
#
#         session_starting_time   booking_id
# 0   2020-01-21 21:10:12+00:00   booking_54
# 2   2019-09-05 09:04:32+00:00    booking_1
# 4   2019-09-07 22:00:05+00:00  booking_240
# ...

# %%
# Display the cleaned DataFrame
Sessions_df_cleaned2.dtypes
# Out:
# session_id                            object
# search_id                             object
# search_time              datetime64[ns, UTC]
# session_starting_time    datetime64[ns, UTC]
# booking_id                            object
# dtype: object

# %%
Sessions_df = Sessions_df_cleaned2
Sessions_df = Sessions_df.reset_index(drop=True)
Sessions_df
# Out:
#      session_id    search_id                      search_time  \
# 0   session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1   session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 2   session_229   search_695 2019-09-07 22:29:05.439000+00:00
# 3   session_285   search_216 2019-09-03 17:29:53.394000+00:00
# 4   session_160   search_451 2020-01-26 13:35:35.117000+00:00
# ..          ...          ...                              ...
# 79  session_161  search_1147 2020-02-04 18:37:12.045000+00:00
# 80  session_135  search_1197 2020-03-18 16:57:45.171000+00:00
# 81   session_56   search_555 2020-03-16 23:44:39.576000+00:00
# 82  session_249  search_1079 2019-07-25 09:53:40.341000+00:00
# 83  session_150   search_156 2018-12-18 22:59:43.764000+00:00
#
#        session_starting_time   booking_id
# 0  2020-01-21 21:10:12+00:00   booking_54
# 1  2019-09-05 09:04:32+00:00    booking_1
# 2  2019-09-07 22:00:05+00:00  booking_240
# 3  2019-09-03 17:29:39+00:00   booking_34
# ...

# %%
Bookings_df
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
Bookings_df.head(10)
# Out:
#     customer_id   booking_id    from_city from_country            to_city  \
# 0  customer_259   booking_82      Gurgaon        India          Ahmedabad
# 1  customer_303  booking_156        Delhi        India           Brussels
# 2  customer_203   booking_99   Devanhalli        India  Frankfurt am Main
# 3  customer_211  booking_319      Gurgaon        India  Frankfurt am Main
# 4  customer_287  booking_222      Gurgaon        India   Roissy-en-France
# 5   customer_99  booking_241      Gurgaon        India   Roissy-en-France
# 6   customer_28  booking_129      Kolkata        India            Gurgaon
# 7  customer_217   booking_18  Bhubaneswar        India            Durlaga
# 8  customer_161  booking_136      Gurgaon        India          Amsterdam
# 9  customer_150  booking_289        Delhi        India            Hamburg
#
#     to_country              booking_time device_type_used  INR_Amount  \
# 0        India 2020-02-05 16:12:08+00:00          Desktop     2565.28
# ...

# %%
Sessions_df.head(10)
# Out:
#     session_id    search_id                      search_time  \
# 0  session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1  session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 2  session_229   search_695 2019-09-07 22:29:05.439000+00:00
# 3  session_285   search_216 2019-09-03 17:29:53.394000+00:00
# 4  session_160   search_451 2020-01-26 13:35:35.117000+00:00
# 5   session_57  search_1277 2018-09-29 13:38:20.074000+00:00
# 6  session_174    search_25 2018-09-29 19:35:13.617000+00:00
# 7  session_167  search_1056 2020-01-24 08:24:58.759000+00:00
# 8  session_261  search_1078 2020-01-24 10:37:10.169000+00:00
# 9  session_128   search_161 2018-09-24 15:03:39.272000+00:00
#
#       session_starting_time   booking_id
# 0 2020-01-21 21:10:12+00:00   booking_54
# 1 2019-09-05 09:04:32+00:00    booking_1
# 2 2019-09-07 22:00:05+00:00  booking_240
# 3 2019-09-03 17:29:39+00:00   booking_34
# 4 2020-01-26 12:56:26+00:00  booking_190
# 5 2018-09-29 13:13:05+00:00   booking_74
# ...

# %% [markdown]
# _**Step 7: Revoving all leading and trailing whitespaces from all the columns**_

# %%
# Using the "apply - function" to strip whitespace from each element in each column if it's a string
for col in Bookings_df.columns:
    if Bookings_df[col].dtype == "object":  # Only apply to columns with dtype object (i.e., strings)
        Bookings_df[col] = Bookings_df[col].apply(lambda x: x.strip() if isinstance(x, str) else x)

print(Bookings_df)
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
for col in Sessions_df.columns:
    if Sessions_df[col].dtype == "object":  # Only apply to columns with dtype object (i.e., strings)
        Sessions_df[col] = Sessions_df[col].apply(lambda x: x.strip() if isinstance(x, str) else x)

print(Sessions_df)
# Out:
#      session_id    search_id                      search_time  \
# 0   session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1   session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 2   session_229   search_695 2019-09-07 22:29:05.439000+00:00
# 3   session_285   search_216 2019-09-03 17:29:53.394000+00:00
# 4   session_160   search_451 2020-01-26 13:35:35.117000+00:00
# ..          ...          ...                              ...
# 79  session_161  search_1147 2020-02-04 18:37:12.045000+00:00
# 80  session_135  search_1197 2020-03-18 16:57:45.171000+00:00
# 81   session_56   search_555 2020-03-16 23:44:39.576000+00:00
# 82  session_249  search_1079 2019-07-25 09:53:40.341000+00:00
# 83  session_150   search_156 2018-12-18 22:59:43.764000+00:00
#
#        session_starting_time   booking_id
# 0  2020-01-21 21:10:12+00:00   booking_54
# 1  2019-09-05 09:04:32+00:00    booking_1
# 2  2019-09-07 22:00:05+00:00  booking_240
# 3  2019-09-03 17:29:39+00:00   booking_34
# ...

# %%
Bookings_df
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
Sessions_df
# Out:
#      session_id    search_id                      search_time  \
# 0   session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1   session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 2   session_229   search_695 2019-09-07 22:29:05.439000+00:00
# 3   session_285   search_216 2019-09-03 17:29:53.394000+00:00
# 4   session_160   search_451 2020-01-26 13:35:35.117000+00:00
# ..          ...          ...                              ...
# 79  session_161  search_1147 2020-02-04 18:37:12.045000+00:00
# 80  session_135  search_1197 2020-03-18 16:57:45.171000+00:00
# 81   session_56   search_555 2020-03-16 23:44:39.576000+00:00
# 82  session_249  search_1079 2019-07-25 09:53:40.341000+00:00
# 83  session_150   search_156 2018-12-18 22:59:43.764000+00:00
#
#        session_starting_time   booking_id
# 0  2020-01-21 21:10:12+00:00   booking_54
# 1  2019-09-05 09:04:32+00:00    booking_1
# 2  2019-09-07 22:00:05+00:00  booking_240
# 3  2019-09-03 17:29:39+00:00   booking_34
# ...

# %% [markdown]
# # 3. Performing thorough examination on the dataframes to ensure data quality and understanding its structure; this is done to be sure our data is ready for futher analysis

# %% [markdown]
# **Step A - Checking for any duplicate value**

# %%
# Checking for duplicate rows using the ".duplicated  function"
duplicates = Bookings_df.duplicated()

print("duplicates")
print("\033[1mThere are no duplicates values in the dataframe:\033[0m")
print(duplicates)
# Out:
# duplicates
# There are no duplicates values in the dataframe:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 334    False
# 335    False
# 336    False
# 337    False
# 338    False
# Length: 339, dtype: bool

# %%
# Checking for duplicate rows using the ".duplicated  function"
duplicates_2 = Sessions_df.duplicated()

print("duplicates")
print("\033[1mThere are no duplicates values in the dataframe:\033[0m")
print(duplicates_2)
# Out:
# duplicates
# There are no duplicates values in the dataframe:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# Length: 84, dtype: bool

# %% [markdown]
# **Step B - Checking for any missing value**

# %%
# Checking for duplicate rows using the ".duplicated  function"
missing_values = Bookings_df.isnull()

print(" There Missing values:")
print("\033[1mThere are no missing values in the dataframe:\033[0m")
print(missing_values)
# Out:
#  There Missing values:
# There are no missing values in the dataframe:
#      customer_id  booking_id  from_city  from_country  to_city  to_country  \
# 0          False       False      False         False    False       False
# 1          False       False      False         False    False       False
# 2          False       False      False         False    False       False
# 3          False       False      False         False    False       False
# 4          False       False      False         False    False       False
# ..           ...         ...        ...           ...      ...         ...
# 334        False       False      False         False    False       False
# 335        False       False      False         False    False       False
# 336        False       False      False         False    False       False
# 337        False       False      False         False    False       False
# 338        False       False      False         False    False       False
# ...

# %%
# Checking for missing values using the ".isna function"
missing_values = Sessions_df.isna()

print("Missing values:")
print("\033[1mThere are no missing values in the dataframe:\033[0m")
print(missing_values)
# Out:
# Missing values:
# There are no missing values in the dataframe:
#     session_id  search_id  search_time  session_starting_time  booking_id
# 0        False      False        False                  False       False
# 1        False      False        False                  False       False
# 2        False      False        False                  False       False
# 3        False      False        False                  False       False
# 4        False      False        False                  False       False
# ..         ...        ...          ...                    ...         ...
# 79       False      False        False                  False       False
# 80       False      False        False                  False       False
# 81       False      False        False                  False       False
# 82       False      False        False                  False       False
# 83       False      False        False                  False       False
#
# ...

# %% [markdown]
# **Step C: Checking Data Types of Variables in The DataFrame**

# %%
#Verify that each column has the correct data type
print(Bookings_df.dtypes)
# Out:
# customer_id                       object
# booking_id                        object
# from_city                         object
# from_country                      object
# to_city                           object
# to_country                        object
# booking_time         datetime64[ns, UTC]
# device_type_used                  object
# INR_Amount                       float64
# service_name                      object
# no_of_passengers                   int64
# days_to_departure                  int64
# distance_km                      float64
# dtype: object

# %%
#Verify that each column has the correct data type
print(Sessions_df.dtypes)
# Out:
# session_id                            object
# search_id                             object
# search_time              datetime64[ns, UTC]
# session_starting_time    datetime64[ns, UTC]
# booking_id                            object
# dtype: object

# %% [markdown]
# **Step D: Checking for an overview or the decriptive statistics of the data distribution in dataframe**

# %%
print(Bookings_df.describe())  # For numerical columns for Bookings_df
print(Bookings_df.describe(include=['object']))  # For categorical columns for Bookings_df
# Out:
#           INR_Amount  no_of_passengers  days_to_departure   distance_km
# count     339.000000        339.000000         339.000000    339.000000
# mean    29327.460708          1.247788          22.348083   4574.309735
# std     28148.851152          0.557854          36.412208   3119.033980
# min      1402.400000          1.000000           0.000000    206.800000
# 25%      7237.530000          1.000000           3.000000   1125.800000
# 50%     23209.600000          1.000000           9.000000   6059.100000
# 75%     39669.200000          1.000000          24.500000   6867.850000
# max    216646.400000          4.000000         311.000000  16520.300000
#         customer_id  booking_id from_city from_country            to_city  \
# count           339         339       339          339                339
# unique          306         339        38            1                 95
# top     customer_97  booking_82   Gurgaon        India  Frankfurt am Main
# ...

# %%
print(Sessions_df.describe())  # For numerical columns for Sessions_df
print(Sessions_df.describe(include=['object']))  # For categorical columns for Sessions_df
# Out:
#          session_id   search_id                          search_time  \
# count            84          84                                   84
# unique           83          84                                  NaN
# top     session_196  search_506                                  NaN
# freq              2           1                                  NaN
# mean            NaN         NaN  2019-11-10 08:54:15.310261760+00:00
# min             NaN         NaN     2018-09-24 15:03:39.272000+00:00
# 25%             NaN         NaN  2019-11-03 16:30:43.841499904+00:00
# 50%             NaN         NaN  2019-12-28 01:23:47.643500032+00:00
# 75%             NaN         NaN  2020-02-03 20:08:22.156499968+00:00
# max             NaN         NaN     2020-03-18 16:57:45.171000+00:00
#
#                       session_starting_time  booking_id
# count                                    84          84
# unique                                  NaN          84
# ...

# %% [markdown]
# **Step E: Checking for a unique values or typos in categorical columns to understand the diversity of entries**

# %%
for col in Bookings_df.select_dtypes(include=['object']).columns:
    print(f"{col} unique values:\n", Bookings_df[col].value_counts())
# Out:
# customer_id unique values:
#  customer_id
# customer_97     4
# customer_160    3
# customer_246    3
# customer_217    3
# customer_230    3
#                ..
# customer_204    1
# customer_294    1
# customer_15     1
# customer_30     1
# customer_241    1
# Name: count, Length: 306, dtype: int64
# booking_id unique values:
#  booking_id
# booking_82     1
# booking_321    1
# booking_68     1
# booking_148    1
# booking_298    1
#               ..
# booking_296    1
# booking_303    1
# booking_29     1
# booking_220    1
# booking_336    1
# Name: count, Length: 339, dtype: int64
# from_city unique values:
#  from_city
# Gurgaon               136
# Mumbai                 34
# Delhi                  29
# Devanhalli             24
# Rāja Sānsi             17
# Chennai                16
# Ahmedabad               8
# New Delhi               7
# Madhyamgram             6
# Bālāpur                 6
# Kochi                   4
# Surat                   4
# ...

# %%
for col in Sessions_df.select_dtypes(include=['object']).columns:
    print(f"{col} unique values:\n", Sessions_df[col].value_counts())
# Out:
# session_id unique values:
#  session_id
# session_196    2
# session_322    1
# session_146    1
# session_214    1
# session_315    1
#               ..
# session_321    1
# session_216    1
# session_15     1
# session_276    1
# session_150    1
# Name: count, Length: 83, dtype: int64
# search_id unique values:
#  search_id
# search_506     1
# search_111     1
# search_182     1
# search_187     1
# search_738     1
#               ..
# search_381     1
# search_743     1
# search_1001    1
# search_1088    1
# search_156     1
# Name: count, Length: 84, dtype: int64
# booking_id unique values:
#  booking_id
# booking_54     1
# booking_309    1
# booking_73     1
# booking_238    1
# booking_33     1
#               ..
# booking_312    1
# booking_62     1
# booking_98     1
# booking_248    1
# booking_120    1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# **Nomalizing and scaling of the data**

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data_Bookings_df = scaler.fit_transform(Bookings_df.select_dtypes(include=[np.number]))

# %%
Bookings_df.head(10)
# Out:
#     customer_id   booking_id    from_city from_country            to_city  \
# 0  customer_259   booking_82      Gurgaon        India          Ahmedabad
# 1  customer_303  booking_156        Delhi        India           Brussels
# 2  customer_203   booking_99   Devanhalli        India  Frankfurt am Main
# 3  customer_211  booking_319      Gurgaon        India  Frankfurt am Main
# 4  customer_287  booking_222      Gurgaon        India   Roissy-en-France
# 5   customer_99  booking_241      Gurgaon        India   Roissy-en-France
# 6   customer_28  booking_129      Kolkata        India            Gurgaon
# 7  customer_217   booking_18  Bhubaneswar        India            Durlaga
# 8  customer_161  booking_136      Gurgaon        India          Amsterdam
# 9  customer_150  booking_289        Delhi        India            Hamburg
#
#     to_country              booking_time device_type_used  INR_Amount  \
# 0        India 2020-02-05 16:12:08+00:00          Desktop     2565.28
# ...

# %%
Sessions_df.head(10)
# Out:
#     session_id    search_id                      search_time  \
# 0  session_322   search_506 2020-01-21 21:10:58.482000+00:00
# 1  session_194   search_312 2019-09-05 09:04:40.423000+00:00
# 2  session_229   search_695 2019-09-07 22:29:05.439000+00:00
# 3  session_285   search_216 2019-09-03 17:29:53.394000+00:00
# 4  session_160   search_451 2020-01-26 13:35:35.117000+00:00
# 5   session_57  search_1277 2018-09-29 13:38:20.074000+00:00
# 6  session_174    search_25 2018-09-29 19:35:13.617000+00:00
# 7  session_167  search_1056 2020-01-24 08:24:58.759000+00:00
# 8  session_261  search_1078 2020-01-24 10:37:10.169000+00:00
# 9  session_128   search_161 2018-09-24 15:03:39.272000+00:00
#
#       session_starting_time   booking_id
# 0 2020-01-21 21:10:12+00:00   booking_54
# 1 2019-09-05 09:04:32+00:00    booking_1
# 2 2019-09-07 22:00:05+00:00  booking_240
# 3 2019-09-03 17:29:39+00:00   booking_34
# 4 2020-01-26 12:56:26+00:00  booking_190
# 5 2018-09-29 13:13:05+00:00   booking_74
# ...

# %% [markdown]
# # 4. After Rigorous Data Wrangling and Cleaning of the data frame to ensure good results, I now proceed to answering the Questions with the Data

# %% [markdown]
# ### Question 1
# #### Find the number of distinct bookings, sessions, and searches from the given data sets.

# %%
# finding dinstict booking using the len and unique functions
distinct_bookings = len(Bookings_df["booking_id"].unique()) # Count distinct bookings

# %%
distinct_sessions = len(Sessions_df["session_id"].unique()) # Count distinct sessions

# %%
distinct_searches = len(Sessions_df["search_id"].unique()) # Count distinct searches

# %%
print("Number of distinct bookings is:", distinct_bookings)
print("Number of distinct sessions is:", distinct_sessions)
print("Number of distinct searches is:", distinct_searches)
# Out:
# Number of distinct bookings is: 339
# Number of distinct sessions is: 83
# Number of distinct searches is: 84

# %% [markdown]
# ### Question 2
# #### How many sessions have more than one booking?

# %%
# Join bookings with sessions to find sessions with bookings
merged_df = pd.merge(Sessions_df, Bookings_df, on="booking_id", how="inner")

# %%
# Group by session_id and count the number of bookings in each session
session_booking_counts = merged_df.groupby("session_id")["booking_id"].count()

# %%
# Filter sessions with morethan one bookings
sessions_with_multiple_bookings = session_booking_counts[session_booking_counts > 1]

# %%
# Get the count of such sessions
num_sessions_with_multiple_bookings = len(sessions_with_multiple_bookings)

# %%
print("Number of sessions with more than one booking is:", num_sessions_with_multiple_bookings)
# Out:
# Number of sessions with more than one booking is: 1

# %% [markdown]
# ### Question 3
# #### Which days of the week have the highest number of bookings?
# #### Also, draw a pie chart to show the distribution for all days of the week?

# %%
import matplotlib.pyplot as plt

# %%
# Extract the day of the week from booking_time
Bookings_df['day_of_week'] = Bookings_df['booking_time'].dt.day_name()

# %%
# Count the number of bookings for each day of the week
Bookings_per_day = Bookings_df['day_of_week'].value_counts()

# %%
# Find the day with the highest number of bookings
day_with_highest_bookings = Bookings_per_day.idxmax()

# %%
print("\033[2mDay with the highest number of bookings is:\033[1m", day_with_highest_bookings)

# Plot a pie chart for the distribution of bookings across days of the week
plt.figure(figsize=(10, 6)) 
Bookings_per_day.plot.pie(autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(7)))
plt.title('Distribution of Bookings Across Days of the Week')

# Hide the y-label for better aesthetics
plt.ylabel('')  
plt.show()
# Out:
# Day with the highest number of bookings is: Thursday

# %% [markdown]
# ### Question 4
# #### For each of the service names, display the total number of bookings and the total Gross Booking Value in INR.

# %%
# Group bookings by service_name
Service_Stats = Bookings_df.groupby('service_name').agg(
    total_bookings=('booking_id', 'count'),
    Total_gross_booking_value=('INR_Amount', 'sum')
).reset_index()

# %%
print("\033[2mThe Number of Total Bookings and Gross Booking Value are:\033[1m")
Service_Stats_reset = Service_Stats.reset_index(drop=True)
Service_Stats_reset.index = Service_Stats_reset.index + 1
Service_Stats_reset
# Out:
# The Number of Total Bookings and Gross Booking Value are:
#   service_name  total_bookings  Total_gross_booking_value
# 1      GOIBIBO             186                 5897637.97
# 2          MMT              48                  665669.08
# 3        YATRA             105                 3378702.13

# %% [markdown]
# ### Question 5
# #### For customers who have more than 1 booking, which is the most booked route (from_city to to_city)?

# %%
# Filter customers who have more than 1 booking
Customer_booking_counts = Bookings_df.groupby('customer_id')['booking_id'].count()
Customers_with_multiple_bookings = Customer_booking_counts[Customer_booking_counts > 1].index

# %%
# Filter the bookings data to include only these customers
Multiple_bookings_df = Bookings_df[Bookings_df['customer_id'].isin(Customers_with_multiple_bookings)]

# %%
# Find the most booked route for these customers
Route_Counts = Multiple_bookings_df.groupby(['from_city', 'to_city']).size().reset_index(name='count') 
Most_Booked_Route = Route_Counts.loc[Route_Counts['count'].idxmax()]

# %%
print("\033[2mMost Booked Route for customers with more than 1 booking:\033[1m")
print(f" The Most Route Booking is From {Most_Booked_Route['from_city']} to {Most_Booked_Route['to_city']} with {Most_Booked_Route['count']} bookings")
# Out:
# Most Booked Route for customers with more than 1 booking:
#  The Most Route Booking is From Gurgaon to Roissy-en-France with 5 bookings

# %% [markdown]
# ### Question 6
# #### Which are the top 3 departure cities from where customers book mostly in advance, provided that there have been at least 5 departures from that city?

# %%
# Filter bookings where days_to_departure > 0
Advance_Bookings_df = Bookings_df[Bookings_df['days_to_departure'] > 0]

# %%
# Group by from_city and calculate the number of advance bookings and average days to departure
City_Advance_Stats = Advance_Bookings_df.groupby('from_city').agg(
    Total_Departures=('booking_id', 'count'),
    Average_Days_to_Departure=('days_to_departure', 'mean')
).reset_index()

# %%
# Filter cities with at least 5 departures
City_Advance_Stats_Filtered = City_Advance_Stats[City_Advance_Stats['Total_Departures'] >= 5]

# %%
# Sort by average days to departure in descending order and select the top 3 cities
top_3_cities = City_Advance_Stats_Filtered.sort_values(by='Average_Days_to_Departure', ascending=False).head(3)

# %%
print("\033[2mTop three departure cities with the most advance bookings (at least 5 departures) are:\033[1m")
# Reset the index
top_3_cities_reset = top_3_cities.reset_index(drop=True)
# Change the index to start from 1
top_3_cities_reset.index = top_3_cities_reset.index + 1 
top_3_cities_reset
# Out:
# Top three departure cities with the most advance bookings (at least 5 departures) are:
#     from_city  Total_Departures  Average_Days_to_Departure
# 1     Bālāpur                 6                  46.166667
# 2  Devanhalli                24                  29.583333
# 3     Gurgaon               131                  27.175573

# %%
# Also Checking for the top most departing cities by total departures in descending order

Top_Three_Cities = top_3_cities_reset.sort_values(by='Total_Departures', ascending=False)
Top_Three_Cities_reset = Top_Three_Cities.reset_index(drop=True)
Top_Three_Cities_reset.index = Top_Three_Cities_reset.index + 1

Top_Three_Most_Departing_Cities = Top_Three_Cities_reset

print("Top three most departing cities with the most total departures are:")
Top_Three_Most_Departing_Cities
# Out:
# Top three most departing cities with the most total departures are:
#     from_city  Total_Departures  Average_Days_to_Departure
# 1     Gurgaon               131                  27.175573
# 2  Devanhalli                24                  29.583333
# 3     Bālāpur                 6                  46.166667

# %% [markdown]
# ### Question 7
# #### Plot a heatmap displaying correlations of the numerical column and report which pair of numerical columns in the bookings data set, have the maximum correlation?

# %%
import seaborn as sns # for data visualization
import matplotlib.pyplot as plt

# %%
# Selecting a numerical columns for correlation analysis in Bookings Data Frame
numerical_columns = Bookings_df.select_dtypes(include='number').columns

# %%
# Computing the correlation matrix by numerical column
correlation_matrix = Bookings_df[numerical_columns].corr()

# %%
# Making a heatmap plot from the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Numerical Columns in Bookings Data')
plt.show()

# Find the pair of numerical columns with the maximum correlation
correlation_unstacked = correlation_matrix.unstack()
# Exclude self-correlation by filtering out 1.0 and taking the absolute value for finding the max correlation
correlation_unstacked = correlation_unstacked[correlation_unstacked < 1].abs()
max_correlation_pair = correlation_unstacked.idxmax()
max_correlation_value = correlation_unstacked.max()

print(f"\033[2mThe pair of numerical columns with the maximum correlation is:\033[1m {max_correlation_pair} with a correlation of {max_correlation_value:.2f}")
# Out:
# The pair of numerical columns with the maximum correlation is: ('INR_Amount', 'distance_km') with a correlation of 0.62

# %% [markdown]
# ### Question 8
# #### For each service, which is the most used device type for making bookings on the platform?

# %%
# Firstly you group bookings by service_name and device_type_used and count the number of bookings for each combination
Device_Usage_Stats = Bookings_df.groupby(['service_name', 'device_type_used']).size().reset_index(name='count')

# %%
# Find the most used device type for each service
Most_Used_Device_by_Service = Device_Usage_Stats.loc[Device_Usage_Stats.groupby('service_name')['count'].idxmax()]

# %%
print("\033[2mMost used device type for each service:\033[1m")

Most_Used_Device_by_Service_reset = Most_Used_Device_by_Service.reset_index(drop=True)

Most_Used_Device_by_Service_reset.index = Most_Used_Device_by_Service_reset.index + 1

Most_Used_Device_by_Service_reset
# Out:
# Most used device type for each service:
#   service_name device_type_used  count
# 1      GOIBIBO              IOS     70
# 2          MMT          Desktop     30
# 3        YATRA          Desktop     51

# %% [markdown]
# ### Question 9
# #### Plot the trends at a quarterly frequency for the number of bookings by each of the device types, that is, plot a time series for each year and quarter showing the number of bookings performed by each device type.

# %%
# Firstly, Confirm the Booking_time is in datetime format
Bookings_df.dtypes
# Out:
# customer_id                       object
# booking_id                        object
# from_city                         object
# from_country                      object
# to_city                           object
# to_country                        object
# booking_time         datetime64[ns, UTC]
# device_type_used                  object
# INR_Amount                       float64
# service_name                      object
# no_of_passengers                   int64
# days_to_departure                  int64
# distance_km                      float64
# day_of_week                       object
# dtype: object

# %%
# Secondly, Set booking_time as the index, since booking_is already in datetime format, it is ready to set the dataframe's index to a specified column
Bookings_df.set_index('booking_time', inplace=True)

# %%
# Resample the data quarterly and count the number of bookings for each device type, thereby aggregating the data for each quarter
Quarterly_Device_Bookings = Bookings_df.groupby('device_type_used').resample('Q').size().unstack(level=0, fill_value=0)

# %%
# Plot the time series for each device type
plt.figure(figsize=(12, 8))
for device_type in Quarterly_Device_Bookings.columns:
    plt.plot(Quarterly_Device_Bookings.index, Quarterly_Device_Bookings[device_type], marker='o', label=device_type)

plt.title('Quarterly Number of Bookings by Device Type')
plt.xlabel('Quarter')
plt.ylabel('Number of Bookings')
plt.legend(title='Device Type')
plt.grid(False)
plt.show()

# %% [markdown]
# ### Question 10
# #### Consider the following example:12 customers performed a total of 100 searches but only a few of them performed 10 bookings in total.
# Searches = 100 bookings = 10 customers ,1 ,
# The overall booking to search rati, Obe, is 10/100 = 0.
# ##### 1 Using the above information/context, answer the follongwi
# ##### • _What is the average oBSR for each month of the year?_
# ##### • _What is the average oBSR for each day of the week?_
# ##### • _Plot a time series of oBSR on all the given datess.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# First, we will calculate the average oBSR for each month and day of the week by merging sessions and bookings dataframe using a leftjoin
merged_sessions_bookings = pd.merge(Sessions_df, Bookings_df, on="booking_id", how="left")

# %%
# Secondly, remove timezone information from the search_time column
merged_sessions_bookings['search_time'] = merged_sessions_bookings['search_time'].dt.tz_localize(None)

# %%
# Thirdly, calculate the number of searches and bookings per month
searches_per_month = merged_sessions_bookings.groupby(merged_sessions_bookings['search_time'].dt.to_period('M')).size()
bookings_per_month = merged_sessions_bookings.dropna(subset=['booking_id']).groupby(merged_sessions_bookings['search_time'].dt.to_period('M')).size()

# %%
# Next is to calculate oBSR per month
obsr_per_month = bookings_per_month / searches_per_month
obsr_per_month = obsr_per_month.fillna(0)  # Fill NaN values with 0

# %%
# Calculate the number of searches and bookings per day of the week
searches_per_day = merged_sessions_bookings.groupby(merged_sessions_bookings['search_time'].dt.day_name()).size()
bookings_per_day = merged_sessions_bookings.dropna(subset=['booking_id']).groupby(merged_sessions_bookings['search_time'].dt.day_name()).size()

# %%
# Calculate oBSR per day of the week
obsr_per_day = bookings_per_day / searches_per_day
obsr_per_day = obsr_per_day.fillna(0)  # Fill NaN values with 0

# %%
# Calculate the number of searches and bookings per day
searches_per_day_series = merged_sessions_bookings.groupby(merged_sessions_bookings['search_time'].dt.date).size()
bookings_per_day_series = merged_sessions_bookings.dropna(subset=['booking_id']).groupby(merged_sessions_bookings['search_time'].dt.date).size()

# %%
# Calculate oBSR per day
obsr_per_day_series = bookings_per_day_series / searches_per_day_series
obsr_per_day_series = obsr_per_day_series.fillna(0)  # Fill NaN values with 0

# %%
# Plot the oBSR per month
plt.figure(figsize=(12, 6))
obsr_per_month.plot(marker='o', linestyle='-', title='Average oBSR per Month')
plt.ylabel('oBSR')
plt.xlabel('Month')
plt.grid(False)
plt.show()

# %%
# Plot the oBSR per day of the week
plt.figure(figsize=(12, 6))
obsr_per_day.plot(kind='bar', title='Average oBSR per Day of the Week')
plt.ylabel('oBSR')
plt.xlabel('Day of the Week')
plt.grid(False)
plt.show()

# %%
# Plot the time series of oBSR per day
plt.figure(figsize=(12, 6))
obsr_per_day_series.plot(marker='o', linestyle='-', title='Time Series of oBSR per Day')
plt.ylabel('oBSR')
plt.xlabel('Date')
plt.grid(False)
plt.show()
